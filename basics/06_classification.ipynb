# %% [markdown]
# # TF Classification

# %%
import pandas as pd

# %%
diabetes = pd.read_csv('data/pima-indians-diabetes.csv')

# %%
diabetes.head()
# Out:
#    Number_pregnant  Glucose_concentration  Blood_pressure   Triceps   Insulin  \
# 0                6               0.743719        0.590164  0.353535  0.000000
# 1                1               0.427136        0.540984  0.292929  0.000000
# 2                8               0.919598        0.524590  0.000000  0.000000
# 3                1               0.447236        0.540984  0.232323  0.111111
# 4                0               0.688442        0.327869  0.353535  0.198582
#
#         BMI  Pedigree  Age  Class Group
# 0  0.500745  0.234415   50      1     B
# 1  0.396423  0.116567   31      0     C
# 2  0.347243  0.253629   32      1     B
# 3  0.418778  0.038002   21      0     B
# 4  0.642325  0.943638   33      1     C

# %%
diabetes.columns
# Out:
# Index(['Number_pregnant', 'Glucose_concentration', 'Blood_pressure', 'Triceps',
#        'Insulin', 'BMI', 'Pedigree', 'Age', 'Class', 'Group'],
#       dtype='object')

# %%
cols_to_norm = ['Number_pregnant', 'Glucose_concentration', 'Blood_pressure', 'Triceps',
       'Insulin', 'BMI', 'Pedigree']

# %%
diabetes[cols_to_norm] = diabetes[cols_to_norm].apply(lambda x: (x - x.min())/(x.max() - x.min()))

# %%
diabetes.head()
# Out:
#    Number_pregnant  Glucose_concentration  Blood_pressure   Triceps   Insulin  \
# 0         0.352941               0.743719        0.590164  0.353535  0.000000
# 1         0.058824               0.427136        0.540984  0.292929  0.000000
# 2         0.470588               0.919598        0.524590  0.000000  0.000000
# 3         0.058824               0.447236        0.540984  0.232323  0.111111
# 4         0.000000               0.688442        0.327869  0.353535  0.198582
#
#         BMI  Pedigree  Age  Class Group
# 0  0.500745  0.234415   50      1     B
# 1  0.396423  0.116567   31      0     C
# 2  0.347243  0.253629   32      1     B
# 3  0.418778  0.038002   21      0     B
# 4  0.642325  0.943638   33      1     C

# %%
import tensorflow as tf

# %%
diabetes.columns
# Out:
# Index(['Number_pregnant', 'Glucose_concentration', 'Blood_pressure', 'Triceps',
#        'Insulin', 'BMI', 'Pedigree', 'Age', 'Class', 'Group'],
#       dtype='object')

# %%
num_preg = tf.feature_column.numeric_column('Number_pregnant')
plasma_gluc = tf.feature_column.numeric_column('Glucose_concentration')
dias_press = tf.feature_column.numeric_column('Blood_pressure')
tricep = tf.feature_column.numeric_column('Triceps')
insulin = tf.feature_column.numeric_column('Insulin')
bmi = tf.feature_column.numeric_column('BMI')
diabetes_pedigree = tf.feature_column.numeric_column('Pedigree')
age = tf.feature_column.numeric_column('Age')

# %%
assigned_group = tf.feature_column.categorical_column_with_vocabulary_list('Group', ['A', 'B', 'C', 'D'])

# %%
# assigned_group = tf.feature_column.categorical_column_with_hash_bucket('Group', hash_bucket_size=10)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
diabetes['Age'].hist(bins=20)

# %%
age_bucket = tf.feature_column.bucketized_column(age, boundaries=[20, 30, 40, 50, 60, 70, 80])

# %%
feat_cols = [num_preg, plasma_gluc, dias_press, tricep, insulin, bmi, diabetes_pedigree, assigned_group, age_bucket]

# %%
x_data = diabetes.drop('Class', axis='columns')

# %%
x_data.head()
# Out:
#    Number_pregnant  Glucose_concentration  Blood_pressure   Triceps   Insulin  \
# 0         0.352941               0.743719        0.590164  0.353535  0.000000
# 1         0.058824               0.427136        0.540984  0.292929  0.000000
# 2         0.470588               0.919598        0.524590  0.000000  0.000000
# 3         0.058824               0.447236        0.540984  0.232323  0.111111
# 4         0.000000               0.688442        0.327869  0.353535  0.198582
#
#         BMI  Pedigree  Age Group
# 0  0.500745  0.234415   50     B
# 1  0.396423  0.116567   31     C
# 2  0.347243  0.253629   32     B
# 3  0.418778  0.038002   21     B
# 4  0.642325  0.943638   33     C

# %%
labels = diabetes['Class']

# %%
labels.head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# 4    1
# Name: Class, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(
    x_data, labels, test_size=0.3, random_state=101)

# %%
input_func = tf.estimator.inputs.pandas_input_fn(x=X_train, y=y_train,
                                                batch_size=10, num_epochs=1000,
                                                shuffle=True)

# %%
model = tf.estimator.LinearClassifier(feature_columns=feat_cols, n_classes=2)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpub65sbtx
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/tmpub65sbtx', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f2969219588>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
model.train(input_fn=input_func, steps=1000)
# Out:
# WARNING:tensorflow:From /home/vasanthakumar/.local/share/virtualenvs/tf_pierian-7Jy-WT6u/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /home/vasanthakumar/.local/share/virtualenvs/tf_pierian-7Jy-WT6u/lib/python3.6/site-packages/tensorflow_estimator/python/estimator/inputs/queues/feeding_queue_runner.py:62: QueueRunner.__init__ (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# WARNING:tensorflow:From /home/vasanthakumar/.local/share/virtualenvs/tf_pierian-7Jy-WT6u/lib/python3.6/site-packages/tensorflow_estimator/python/estimator/inputs/queues/feeding_functions.py:500: add_queue_runner (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From /home/vasanthakumar/.local/share/virtualenvs/tf_pierian-7Jy-WT6u/lib/python3.6/site-packages/tensorflow/python/feature_column/feature_column_v2.py:2703: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /home/vasanthakumar/.local/share/virtualenvs/tf_pierian-7Jy-WT6u/lib/python3.6/site-packages/tensorflow/python/feature_column/feature_column_v2.py:2898: to_int64 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# WARNING:tensorflow:From /home/vasanthakumar/.local/share/virtualenvs/tf_pierian-7Jy-WT6u/lib/python3.6/site-packages/tensorflow/python/training/monitored_session.py:809: start_queue_runners (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# INFO:tensorflow:Saving checkpoints for 0 into /tmp/tmpub65sbtx/model.ckpt.
# INFO:tensorflow:loss = 6.931472, step = 1
# INFO:tensorflow:global_step/sec: 269.148
# INFO:tensorflow:loss = 4.227296, step = 101 (0.376 sec)
# INFO:tensorflow:global_step/sec: 395.366
# INFO:tensorflow:loss = 5.18898, step = 201 (0.253 sec)
# INFO:tensorflow:global_step/sec: 377.565
# INFO:tensorflow:loss = 7.4456673, step = 301 (0.265 sec)
# INFO:tensorflow:global_step/sec: 336.797
# INFO:tensorflow:loss = 4.5513544, step = 401 (0.292 sec)
# INFO:tensorflow:global_step/sec: 322.914
# INFO:tensorflow:loss = 5.9980087, step = 501 (0.309 sec)
# INFO:tensorflow:global_step/sec: 319.326
# INFO:tensorflow:loss = 8.22693, step = 601 (0.315 sec)
# INFO:tensorflow:global_step/sec: 281.535
# INFO:tensorflow:loss = 4.1318846, step = 701 (0.358 sec)
# INFO:tensorflow:global_step/sec: 249.479
# INFO:tensorflow:loss = 5.778097, step = 801 (0.399 sec)
# INFO:tensorflow:global_step/sec: 279.602
# INFO:tensorflow:loss = 3.7795696, step = 901 (0.356 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into /tmp/tmpub65sbtx/model.ckpt.
# INFO:tensorflow:Loss for final step: 3.9713829.

# %%
eval_input_fn = tf.estimator.inputs.pandas_input_fn(x=X_test, y=y_test,
                                                   batch_size=10, num_epochs=1,
                                                   shuffle=False)

# %%
results = model.evaluate(eval_input_fn)
# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From /home/vasanthakumar/.local/share/virtualenvs/tf_pierian-7Jy-WT6u/lib/python3.6/site-packages/tensorflow/python/ops/metrics_impl.py:2002: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-03-06T12:24:06Z
# INFO:tensorflow:Graph was finalized.
# WARNING:tensorflow:From /home/vasanthakumar/.local/share/virtualenvs/tf_pierian-7Jy-WT6u/lib/python3.6/site-packages/tensorflow/python/training/saver.py:1266: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# INFO:tensorflow:Restoring parameters from /tmp/tmpub65sbtx/model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-03-06-12:24:07
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.74025977, accuracy_baseline = 0.64935064, auc = 0.8004115, auc_precision_recall = 0.6469919, average_loss = 0.525456, global_step = 1000, label/mean = 0.35064936, loss = 5.057514, precision = 0.6615385, prediction/mean = 0.36392432, recall = 0.5308642
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1000: /tmp/tmpub65sbtx/model.ckpt-1000

# %%
results
# Out:
# {'accuracy': 0.74025977,
#  'accuracy_baseline': 0.64935064,
#  'auc': 0.8004115,
#  'auc_precision_recall': 0.6469919,
#  'average_loss': 0.525456,
#  'label/mean': 0.35064936,
#  'loss': 5.057514,
#  'precision': 0.6615385,
#  'prediction/mean': 0.36392432,
#  'recall': 0.5308642,
#  'global_step': 1000}

# %%
pred_input_func = tf.estimator.inputs.pandas_input_fn(x=X_test, batch_size=10,
                                                     num_epochs=1, shuffle=False)

# %%
predictions = model.predict(pred_input_func)

# %%
my_pred = list(predictions)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpub65sbtx/model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.

# %%
my_pred
# Out:
# [{'logits': array([0.0771966], dtype=float32),
#   'logistic': array([0.51928955], dtype=float32),
#   'probabilities': array([0.4807104 , 0.51928955], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.53609216], dtype=float32),
#   'logistic': array([0.6309029], dtype=float32),
#   'probabilities': array([0.36909708, 0.6309028 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.550146], dtype=float32),
#   'logistic': array([0.36583054], dtype=float32),
#   'probabilities': array([0.6341694, 0.3658305], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.67973167], dtype=float32),
#   'logistic': array([0.33632123], dtype=float32),
#   'probabilities': array([0.6636788, 0.3363212], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.7596275], dtype=float32),
#   'logistic': array([0.146837], dtype=float32),
#   'probabilities': array([0.85316294, 0.146837  ], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.79931974], dtype=float32),
#   'logistic': array([0.68982893], dtype=float32),
#   'probabilities': array([0.31017104, 0.68982893], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.41509962], dtype=float32),
#   'logistic': array([0.60231], dtype=float32),
#   'probabilities': array([0.39768997, 0.60231006], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.70514214], dtype=float32),
#   'logistic': array([0.33067316], dtype=float32),
#   'probabilities': array([0.66932684, 0.33067313], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.1555927], dtype=float32),
#   'logistic': array([0.23946904], dtype=float32),
#   'probabilities': array([0.76053095, 0.23946904], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.1192257], dtype=float32),
#   'logistic': array([0.24615495], dtype=float32),
#   'probabilities': array([0.7538451 , 0.24615493], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.8726885], dtype=float32),
#   'logistic': array([0.13323092], dtype=float32),
#   'probabilities': array([0.866769  , 0.13323094], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.6997101], dtype=float32),
#   'logistic': array([0.1545031], dtype=float32),
#   'probabilities': array([0.84549683, 0.15450312], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.89272505], dtype=float32),
#   'logistic': array([0.2905478], dtype=float32),
#   'probabilities': array([0.70945215, 0.29054776], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.22724748], dtype=float32),
#   'logistic': array([0.5565686], dtype=float32),
#   'probabilities': array([0.44343135, 0.5565686 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.5407337], dtype=float32),
#   'logistic': array([0.17642865], dtype=float32),
#   'probabilities': array([0.8235714 , 0.17642865], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.67580914], dtype=float32),
#   'logistic': array([0.3371973], dtype=float32),
#   'probabilities': array([0.6628027, 0.3371973], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.52837473], dtype=float32),
#   'logistic': array([0.37089604], dtype=float32),
#   'probabilities': array([0.62910396, 0.37089604], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.9066511], dtype=float32),
#   'logistic': array([0.12935755], dtype=float32),
#   'probabilities': array([0.8706425 , 0.12935756], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.57647496], dtype=float32),
#   'logistic': array([0.3597441], dtype=float32),
#   'probabilities': array([0.64025587, 0.3597441 ], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.7736249], dtype=float32),
#   'logistic': array([0.14509211], dtype=float32),
#   'probabilities': array([0.8549079 , 0.14509211], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.2805495], dtype=float32),
#   'logistic': array([0.21745667], dtype=float32),
#   'probabilities': array([0.78254336, 0.2174567 ], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.8776461], dtype=float32),
#   'logistic': array([0.29366583], dtype=float32),
#   'probabilities': array([0.70633423, 0.29366583], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.602005], dtype=float32),
#   'logistic': array([0.6461149], dtype=float32),
#   'probabilities': array([0.3538851, 0.6461149], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.3108833], dtype=float32),
#   'logistic': array([0.2123391], dtype=float32),
#   'probabilities': array([0.78766096, 0.21233907], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.51715], dtype=float32),
#   'logistic': array([0.17988157], dtype=float32),
#   'probabilities': array([0.8201185 , 0.17988159], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([1.2066694], dtype=float32),
#   'logistic': array([0.7697091], dtype=float32),
#   'probabilities': array([0.23029089, 0.7697091 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.5438299], dtype=float32),
#   'logistic': array([0.1759792], dtype=float32),
#   'probabilities': array([0.82402074, 0.1759792 ], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.7660732], dtype=float32),
#   'logistic': array([0.31732917], dtype=float32),
#   'probabilities': array([0.68267083, 0.31732914], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-2.1456618], dtype=float32),
#   'logistic': array([0.10473731], dtype=float32),
#   'probabilities': array([0.8952627, 0.1047373], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.2914815], dtype=float32),
#   'logistic': array([0.5723588], dtype=float32),
#   'probabilities': array([0.4276412, 0.5723588], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([2.7371006], dtype=float32),
#   'logistic': array([0.9391807], dtype=float32),
#   'probabilities': array([0.06081931, 0.9391807 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.36972344], dtype=float32),
#   'logistic': array([0.40860787], dtype=float32),
#   'probabilities': array([0.59139216, 0.40860784], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.7316294], dtype=float32),
#   'logistic': array([0.32483727], dtype=float32),
#   'probabilities': array([0.67516273, 0.3248373 ], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.17649996], dtype=float32),
#   'logistic': array([0.5440108], dtype=float32),
#   'probabilities': array([0.4559892, 0.5440108], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.1347791], dtype=float32),
#   'logistic': array([0.2432802], dtype=float32),
#   'probabilities': array([0.75671977, 0.24328022], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.5302893], dtype=float32),
#   'logistic': array([0.37044942], dtype=float32),
#   'probabilities': array([0.6295506, 0.3704494], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.04355228], dtype=float32),
#   'logistic': array([0.48911366], dtype=float32),
#   'probabilities': array([0.5108864 , 0.48911366], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.4685415], dtype=float32),
#   'logistic': array([0.6150385], dtype=float32),
#   'probabilities': array([0.3849615 , 0.61503845], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([1.0976142], dtype=float32),
#   'logistic': array([0.7498128], dtype=float32),
#   'probabilities': array([0.2501872, 0.7498128], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.6679186], dtype=float32),
#   'logistic': array([0.33896306], dtype=float32),
#   'probabilities': array([0.66103697, 0.33896306], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.5122899], dtype=float32),
#   'logistic': array([0.18059969], dtype=float32),
#   'probabilities': array([0.8194003 , 0.18059967], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.18637633], dtype=float32),
#   'logistic': array([0.5464597], dtype=float32),
#   'probabilities': array([0.45354033, 0.5464597 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.6991439], dtype=float32),
#   'logistic': array([0.15457708], dtype=float32),
#   'probabilities': array([0.84542286, 0.1545771 ], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.09774423], dtype=float32),
#   'logistic': array([0.5244166], dtype=float32),
#   'probabilities': array([0.4755834, 0.5244166], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.8007474], dtype=float32),
#   'logistic': array([0.14176008], dtype=float32),
#   'probabilities': array([0.8582398, 0.1417601], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-2.0255036], dtype=float32),
#   'logistic': array([0.1165511], dtype=float32),
#   'probabilities': array([0.8834489, 0.1165511], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.38047504], dtype=float32),
#   'logistic': array([0.59398764], dtype=float32),
#   'probabilities': array([0.40601233, 0.59398764], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.494404], dtype=float32),
#   'logistic': array([0.18326163], dtype=float32),
#   'probabilities': array([0.81673837, 0.18326165], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.406925], dtype=float32),
#   'logistic': array([0.19671951], dtype=float32),
#   'probabilities': array([0.8032805 , 0.19671953], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.9240512], dtype=float32),
#   'logistic': array([0.12741049], dtype=float32),
#   'probabilities': array([0.8725895 , 0.12741049], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.5417495], dtype=float32),
#   'logistic': array([0.17628112], dtype=float32),
#   'probabilities': array([0.82371885, 0.1762811 ], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.1352088], dtype=float32),
#   'logistic': array([0.24320114], dtype=float32),
#   'probabilities': array([0.7567989, 0.2432011], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.044356], dtype=float32),
#   'logistic': array([0.26031038], dtype=float32),
#   'probabilities': array([0.7396896 , 0.26031038], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.5204313], dtype=float32),
#   'logistic': array([0.3727514], dtype=float32),
#   'probabilities': array([0.6272486 , 0.37275138], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.8956566], dtype=float32),
#   'logistic': array([0.13060084], dtype=float32),
#   'probabilities': array([0.86939913, 0.13060085], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.2306004], dtype=float32),
#   'logistic': array([0.22607636], dtype=float32),
#   'probabilities': array([0.77392364, 0.22607636], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.3134322], dtype=float32),
#   'logistic': array([0.21191308], dtype=float32),
#   'probabilities': array([0.7880869 , 0.21191306], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.2892891], dtype=float32),
#   'logistic': array([0.21597314], dtype=float32),
#   'probabilities': array([0.7840268 , 0.21597314], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.12802225], dtype=float32),
#   'logistic': array([0.46803808], dtype=float32),
#   'probabilities': array([0.5319619 , 0.46803808], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.6104581], dtype=float32),
#   'logistic': array([0.16652502], dtype=float32),
#   'probabilities': array([0.833475  , 0.16652502], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.2080053], dtype=float32),
#   'logistic': array([0.2300542], dtype=float32),
#   'probabilities': array([0.7699458 , 0.23005417], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.49977398], dtype=float32),
#   'logistic': array([0.62240624], dtype=float32),
#   'probabilities': array([0.3775938 , 0.62240624], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.4600054], dtype=float32),
#   'logistic': array([0.6130155], dtype=float32),
#   'probabilities': array([0.38698456, 0.6130155 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.00217855], dtype=float32),
#   'logistic': array([0.49945536], dtype=float32),
#   'probabilities': array([0.5005446 , 0.49945533], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.53925693], dtype=float32),
#   'logistic': array([0.36836046], dtype=float32),
#   'probabilities': array([0.63163954, 0.36836046], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.06522238], dtype=float32),
#   'logistic': array([0.4837002], dtype=float32),
#   'probabilities': array([0.5162998 , 0.48370016], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.4762127], dtype=float32),
#   'logistic': array([0.18600017], dtype=float32),
#   'probabilities': array([0.81399983, 0.18600014], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.3993715], dtype=float32),
#   'logistic': array([0.19791585], dtype=float32),
#   'probabilities': array([0.80208415, 0.19791587], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.7383442], dtype=float32),
#   'logistic': array([0.14952338], dtype=float32),
#   'probabilities': array([0.8504766 , 0.14952338], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.8963265], dtype=float32),
#   'logistic': array([0.1305248], dtype=float32),
#   'probabilities': array([0.8694752, 0.1305248], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.4516809], dtype=float32),
#   'logistic': array([0.6110388], dtype=float32),
#   'probabilities': array([0.3889612, 0.6110388], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.1947416], dtype=float32),
#   'logistic': array([0.23241198], dtype=float32),
#   'probabilities': array([0.767588  , 0.23241197], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.25461096], dtype=float32),
#   'logistic': array([0.43668893], dtype=float32),
#   'probabilities': array([0.5633111, 0.4366889], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.28143466], dtype=float32),
#   'logistic': array([0.5698979], dtype=float32),
#   'probabilities': array([0.4301021 , 0.56989795], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.8401614], dtype=float32),
#   'logistic': array([0.30150083], dtype=float32),
#   'probabilities': array([0.6984992, 0.3015008], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.52191687], dtype=float32),
#   'logistic': array([0.6275959], dtype=float32),
#   'probabilities': array([0.3724041, 0.6275959], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.9207892], dtype=float32),
#   'logistic': array([0.12777358], dtype=float32),
#   'probabilities': array([0.8722264 , 0.12777358], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.46580732], dtype=float32),
#   'logistic': array([0.6143909], dtype=float32),
#   'probabilities': array([0.38560906, 0.6143909 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.9182204], dtype=float32),
#   'logistic': array([0.12806015], dtype=float32),
#   'probabilities': array([0.87193984, 0.12806015], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.22998703], dtype=float32),
#   'logistic': array([0.55724466], dtype=float32),
#   'probabilities': array([0.44275534, 0.55724466], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.6881126], dtype=float32),
#   'logistic': array([0.33445308], dtype=float32),
#   'probabilities': array([0.6655469 , 0.33445302], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.6331458], dtype=float32),
#   'logistic': array([0.16339985], dtype=float32),
#   'probabilities': array([0.8366001 , 0.16339988], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.18519628], dtype=float32),
#   'logistic': array([0.5461672], dtype=float32),
#   'probabilities': array([0.45383283, 0.5461672 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.38630438], dtype=float32),
#   'logistic': array([0.5953927], dtype=float32),
#   'probabilities': array([0.40460727, 0.59539276], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.18452466], dtype=float32),
#   'logistic': array([0.5460007], dtype=float32),
#   'probabilities': array([0.4539993, 0.5460007], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.6002159], dtype=float32),
#   'logistic': array([0.16795143], dtype=float32),
#   'probabilities': array([0.8320486 , 0.16795145], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.5701161], dtype=float32),
#   'logistic': array([0.36121005], dtype=float32),
#   'probabilities': array([0.63879   , 0.36121008], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.7447113], dtype=float32),
#   'logistic': array([0.14871553], dtype=float32),
#   'probabilities': array([0.8512845, 0.1487155], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.8148606], dtype=float32),
#   'logistic': array([0.69314426], dtype=float32),
#   'probabilities': array([0.30685568, 0.69314426], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([1.4114541], dtype=float32),
#   'logistic': array([0.80399525], dtype=float32),
#   'probabilities': array([0.19600482, 0.80399525], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.45553792], dtype=float32),
#   'logistic': array([0.6119551], dtype=float32),
#   'probabilities': array([0.38804486, 0.6119551 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.3096732], dtype=float32),
#   'logistic': array([0.21254155], dtype=float32),
#   'probabilities': array([0.7874585 , 0.21254154], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.16081625], dtype=float32),
#   'logistic': array([0.45988238], dtype=float32),
#   'probabilities': array([0.5401176 , 0.45988235], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.49163443], dtype=float32),
#   'logistic': array([0.3795086], dtype=float32),
#   'probabilities': array([0.6204914, 0.3795086], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.23753232], dtype=float32),
#   'logistic': array([0.44089457], dtype=float32),
#   'probabilities': array([0.55910546, 0.44089457], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.6005987], dtype=float32),
#   'logistic': array([0.35420674], dtype=float32),
#   'probabilities': array([0.64579326, 0.35420674], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.25725102], dtype=float32),
#   'logistic': array([0.4360396], dtype=float32),
#   'probabilities': array([0.56396043, 0.4360396 ], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.6988472], dtype=float32),
#   'logistic': array([0.15461588], dtype=float32),
#   'probabilities': array([0.8453841, 0.1546159], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.17320228], dtype=float32),
#   'logistic': array([0.5431927], dtype=float32),
#   'probabilities': array([0.45680737, 0.5431927 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.12130952], dtype=float32),
#   'logistic': array([0.53029025], dtype=float32),
#   'probabilities': array([0.46970975, 0.53029025], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.153562], dtype=float32),
#   'logistic': array([0.23983908], dtype=float32),
#   'probabilities': array([0.76016086, 0.23983906], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.5383614], dtype=float32),
#   'logistic': array([0.17677361], dtype=float32),
#   'probabilities': array([0.8232264 , 0.17677361], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.5642586], dtype=float32),
#   'logistic': array([0.17303643], dtype=float32),
#   'probabilities': array([0.8269636 , 0.17303641], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.9346695], dtype=float32),
#   'logistic': array([0.28197834], dtype=float32),
#   'probabilities': array([0.71802163, 0.2819783 ], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.50144964], dtype=float32),
#   'logistic': array([0.37720007], dtype=float32),
#   'probabilities': array([0.62279993, 0.37720004], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.8244438], dtype=float32),
#   'logistic': array([0.1389015], dtype=float32),
#   'probabilities': array([0.86109847, 0.1389015 ], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.72544485], dtype=float32),
#   'logistic': array([0.32619512], dtype=float32),
#   'probabilities': array([0.6738049 , 0.32619512], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.2015489], dtype=float32),
#   'logistic': array([0.2311998], dtype=float32),
#   'probabilities': array([0.7688002 , 0.23119979], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-2.2464595], dtype=float32),
#   'logistic': array([0.0956553], dtype=float32),
#   'probabilities': array([0.9043447, 0.0956553], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.9115729], dtype=float32),
#   'logistic': array([0.12880425], dtype=float32),
#   'probabilities': array([0.87119573, 0.12880424], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([1.0403], dtype=float32),
#   'logistic': array([0.7389079], dtype=float32),
#   'probabilities': array([0.26109213, 0.7389079 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.5231254], dtype=float32),
#   'logistic': array([0.17900172], dtype=float32),
#   'probabilities': array([0.82099825, 0.17900175], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.8805223], dtype=float32),
#   'logistic': array([0.13232887], dtype=float32),
#   'probabilities': array([0.86767113, 0.1323289 ], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.764821], dtype=float32),
#   'logistic': array([0.14618757], dtype=float32),
#   'probabilities': array([0.8538124 , 0.14618756], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.02891886], dtype=float32),
#   'logistic': array([0.4927708], dtype=float32),
#   'probabilities': array([0.5072292, 0.4927708], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.20718849], dtype=float32),
#   'logistic': array([0.44838738], dtype=float32),
#   'probabilities': array([0.5516126 , 0.44838738], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.1352236], dtype=float32),
#   'logistic': array([0.24319842], dtype=float32),
#   'probabilities': array([0.7568016 , 0.24319838], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.22645527], dtype=float32),
#   'logistic': array([0.44362688], dtype=float32),
#   'probabilities': array([0.5563731 , 0.44362688], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.4563795], dtype=float32),
#   'logistic': array([0.18902169], dtype=float32),
#   'probabilities': array([0.8109783 , 0.18902169], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.1802231], dtype=float32),
#   'logistic': array([0.23501208], dtype=float32),
#   'probabilities': array([0.7649879 , 0.23501207], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.03767037], dtype=float32),
#   'logistic': array([0.50941646], dtype=float32),
#   'probabilities': array([0.4905835 , 0.50941646], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.06861901], dtype=float32),
#   'logistic': array([0.48285198], dtype=float32),
#   'probabilities': array([0.517148  , 0.48285195], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.8319662], dtype=float32),
#   'logistic': array([0.13800421], dtype=float32),
#   'probabilities': array([0.8619958 , 0.13800421], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.45220286], dtype=float32),
#   'logistic': array([0.38883716], dtype=float32),
#   'probabilities': array([0.61116284, 0.38883713], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.6949221], dtype=float32),
#   'logistic': array([0.667061], dtype=float32),
#   'probabilities': array([0.33293903, 0.667061  ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.14505279], dtype=float32),
#   'logistic': array([0.53619975], dtype=float32),
#   'probabilities': array([0.46380025, 0.53619975], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.46377075], dtype=float32),
#   'logistic': array([0.3860917], dtype=float32),
#   'probabilities': array([0.61390835, 0.38609168], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.2687248], dtype=float32),
#   'logistic': array([0.5667798], dtype=float32),
#   'probabilities': array([0.4332202 , 0.56677985], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.2461015], dtype=float32),
#   'logistic': array([0.22337572], dtype=float32),
#   'probabilities': array([0.7766243 , 0.22337572], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.4203395], dtype=float32),
#   'logistic': array([0.19460838], dtype=float32),
#   'probabilities': array([0.8053916 , 0.19460838], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.8610945], dtype=float32),
#   'logistic': array([0.13457549], dtype=float32),
#   'probabilities': array([0.8654245 , 0.13457555], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.0287911], dtype=float32),
#   'logistic': array([0.26331857], dtype=float32),
#   'probabilities': array([0.73668146, 0.26331854], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.02306545], dtype=float32),
#   'logistic': array([0.4942339], dtype=float32),
#   'probabilities': array([0.5057661 , 0.49423388], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.68684256], dtype=float32),
#   'logistic': array([0.6652642], dtype=float32),
#   'probabilities': array([0.33473584, 0.6652642 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.1821679], dtype=float32),
#   'logistic': array([0.23466265], dtype=float32),
#   'probabilities': array([0.76533735, 0.23466264], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.6486615], dtype=float32),
#   'logistic': array([0.16128993], dtype=float32),
#   'probabilities': array([0.83871007, 0.16128995], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.31752586], dtype=float32),
#   'logistic': array([0.42127883], dtype=float32),
#   'probabilities': array([0.57872117, 0.4212788 ], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.2104043], dtype=float32),
#   'logistic': array([0.22962955], dtype=float32),
#   'probabilities': array([0.7703705 , 0.22962953], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.7704129], dtype=float32),
#   'logistic': array([0.14549099], dtype=float32),
#   'probabilities': array([0.854509  , 0.14549097], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.4746177], dtype=float32),
#   'logistic': array([0.18624176], dtype=float32),
#   'probabilities': array([0.81375825, 0.18624176], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.9237647], dtype=float32),
#   'logistic': array([0.12744233], dtype=float32),
#   'probabilities': array([0.87255764, 0.12744235], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.40006673], dtype=float32),
#   'logistic': array([0.40129632], dtype=float32),
#   'probabilities': array([0.5987037 , 0.40129632], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([1.1389416], dtype=float32),
#   'logistic': array([0.7574853], dtype=float32),
#   'probabilities': array([0.24251473, 0.7574853 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([1.1417164], dtype=float32),
#   'logistic': array([0.7579946], dtype=float32),
#   'probabilities': array([0.24200535, 0.7579946 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.09875786], dtype=float32),
#   'logistic': array([0.5246694], dtype=float32),
#   'probabilities': array([0.47533056, 0.5246694 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.0065397], dtype=float32),
#   'logistic': array([0.49836507], dtype=float32),
#   'probabilities': array([0.5016349 , 0.49836504], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.24102604], dtype=float32),
#   'logistic': array([0.5599665], dtype=float32),
#   'probabilities': array([0.44003347, 0.55996644], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-2.049805], dtype=float32),
#   'logistic': array([0.11407208], dtype=float32),
#   'probabilities': array([0.8859279, 0.1140721], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.12687147], dtype=float32),
#   'logistic': array([0.5316754], dtype=float32),
#   'probabilities': array([0.4683246, 0.5316754], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([1.1436602], dtype=float32),
#   'logistic': array([0.75835097], dtype=float32),
#   'probabilities': array([0.24164897, 0.75835097], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.38680583], dtype=float32),
#   'logistic': array([0.40448648], dtype=float32),
#   'probabilities': array([0.5955135 , 0.40448645], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.0169902], dtype=float32),
#   'logistic': array([0.2656141], dtype=float32),
#   'probabilities': array([0.7343859 , 0.26561406], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.69373965], dtype=float32),
#   'logistic': array([0.3332017], dtype=float32),
#   'probabilities': array([0.6667983 , 0.33320168], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.30032134], dtype=float32),
#   'logistic': array([0.57452106], dtype=float32),
#   'probabilities': array([0.42547894, 0.57452106], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.1766979], dtype=float32),
#   'logistic': array([0.23564643], dtype=float32),
#   'probabilities': array([0.7643535 , 0.23564644], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.5978234], dtype=float32),
#   'logistic': array([0.6451582], dtype=float32),
#   'probabilities': array([0.3548418, 0.6451582], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.33563417], dtype=float32),
#   'logistic': array([0.4168704], dtype=float32),
#   'probabilities': array([0.58312964, 0.4168704 ], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.3572026], dtype=float32),
#   'logistic': array([0.41163692], dtype=float32),
#   'probabilities': array([0.5883631 , 0.41163692], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.6700734], dtype=float32),
#   'logistic': array([0.1584144], dtype=float32),
#   'probabilities': array([0.8415856, 0.1584144], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.4264548], dtype=float32),
#   'logistic': array([0.19365168], dtype=float32),
#   'probabilities': array([0.8063483 , 0.19365166], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.4959573], dtype=float32),
#   'logistic': array([0.18302923], dtype=float32),
#   'probabilities': array([0.8169707 , 0.18302925], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.25715798], dtype=float32),
#   'logistic': array([0.43606248], dtype=float32),
#   'probabilities': array([0.56393754, 0.43606248], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.7368007], dtype=float32),
#   'logistic': array([0.14971974], dtype=float32),
#   'probabilities': array([0.8502802 , 0.14971976], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.9762007], dtype=float32),
#   'logistic': array([0.7263537], dtype=float32),
#   'probabilities': array([0.2736463, 0.7263537], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.415023], dtype=float32),
#   'logistic': array([0.195443], dtype=float32),
#   'probabilities': array([0.80455697, 0.195443  ], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.02967966], dtype=float32),
#   'logistic': array([0.49258062], dtype=float32),
#   'probabilities': array([0.50741935, 0.49258062], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.6901877], dtype=float32),
#   'logistic': array([0.15575117], dtype=float32),
#   'probabilities': array([0.8442488 , 0.15575115], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.6797259], dtype=float32),
#   'logistic': array([0.6636775], dtype=float32),
#   'probabilities': array([0.3363225, 0.6636775], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.7872175], dtype=float32),
#   'logistic': array([0.31276643], dtype=float32),
#   'probabilities': array([0.68723357, 0.31276646], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.3874078], dtype=float32),
#   'logistic': array([0.19982192], dtype=float32),
#   'probabilities': array([0.8001781 , 0.19982192], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.69204915], dtype=float32),
#   'logistic': array([0.3335774], dtype=float32),
#   'probabilities': array([0.6664226, 0.3335774], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.7058072], dtype=float32),
#   'logistic': array([0.33052596], dtype=float32),
#   'probabilities': array([0.669474  , 0.33052593], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.558532], dtype=float32),
#   'logistic': array([0.17385742], dtype=float32),
#   'probabilities': array([0.8261426 , 0.17385739], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.8497735], dtype=float32),
#   'logistic': array([0.7005196], dtype=float32),
#   'probabilities': array([0.2994804, 0.7005197], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.4037127], dtype=float32),
#   'logistic': array([0.1972276], dtype=float32),
#   'probabilities': array([0.8027724 , 0.19722761], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.5307695], dtype=float32),
#   'logistic': array([0.17788112], dtype=float32),
#   'probabilities': array([0.8221188 , 0.17788112], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.0036671], dtype=float32),
#   'logistic': array([0.26822105], dtype=float32),
#   'probabilities': array([0.731779  , 0.26822105], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.19265205], dtype=float32),
#   'logistic': array([0.45198542], dtype=float32),
#   'probabilities': array([0.5480146, 0.4519854], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.0175145], dtype=float32),
#   'logistic': array([0.26551184], dtype=float32),
#   'probabilities': array([0.7344881 , 0.26551184], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.972518], dtype=float32),
#   'logistic': array([0.12211869], dtype=float32),
#   'probabilities': array([0.8778813 , 0.12211869], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([1.6195904], dtype=float32),
#   'logistic': array([0.8347386], dtype=float32),
#   'probabilities': array([0.16526136, 0.8347386 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.64256], dtype=float32),
#   'logistic': array([0.6553319], dtype=float32),
#   'probabilities': array([0.34466812, 0.65533197], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.01802814], dtype=float32),
#   'logistic': array([0.5045069], dtype=float32),
#   'probabilities': array([0.49549305, 0.5045069 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.930266], dtype=float32),
#   'logistic': array([0.71712923], dtype=float32),
#   'probabilities': array([0.28287074, 0.71712923], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.9704933], dtype=float32),
#   'logistic': array([0.12233588], dtype=float32),
#   'probabilities': array([0.8776641 , 0.12233592], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.7691141], dtype=float32),
#   'logistic': array([0.1456525], dtype=float32),
#   'probabilities': array([0.85434747, 0.14565253], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.2906932], dtype=float32),
#   'logistic': array([0.2157355], dtype=float32),
#   'probabilities': array([0.78426456, 0.21573551], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.6944084], dtype=float32),
#   'logistic': array([0.3330531], dtype=float32),
#   'probabilities': array([0.6669469, 0.3330531], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.52416205], dtype=float32),
#   'logistic': array([0.37187952], dtype=float32),
#   'probabilities': array([0.6281205 , 0.37187952], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.18573678], dtype=float32),
#   'logistic': array([0.5463011], dtype=float32),
#   'probabilities': array([0.4536988, 0.5463011], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.21826601], dtype=float32),
#   'logistic': array([0.5543509], dtype=float32),
#   'probabilities': array([0.44564912, 0.5543509 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.43993878], dtype=float32),
#   'logistic': array([0.39175558], dtype=float32),
#   'probabilities': array([0.6082444 , 0.39175555], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.580498], dtype=float32),
#   'logistic': array([0.35881805], dtype=float32),
#   'probabilities': array([0.64118195, 0.358818  ], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.6319938], dtype=float32),
#   'logistic': array([0.3470586], dtype=float32),
#   'probabilities': array([0.6529414, 0.3470586], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.4406025], dtype=float32),
#   'logistic': array([0.19145206], dtype=float32),
#   'probabilities': array([0.8085479 , 0.19145206], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.49891472], dtype=float32),
#   'logistic': array([0.62220424], dtype=float32),
#   'probabilities': array([0.37779576, 0.62220424], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.8947588], dtype=float32),
#   'logistic': array([0.13070282], dtype=float32),
#   'probabilities': array([0.86929715, 0.13070282], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.139833], dtype=float32),
#   'logistic': array([0.24235103], dtype=float32),
#   'probabilities': array([0.757649  , 0.24235104], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.16967726], dtype=float32),
#   'logistic': array([0.5423178], dtype=float32),
#   'probabilities': array([0.45768216, 0.5423178 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.63339126], dtype=float32),
#   'logistic': array([0.34674197], dtype=float32),
#   'probabilities': array([0.653258, 0.346742], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.4212797], dtype=float32),
#   'logistic': array([0.19446105], dtype=float32),
#   'probabilities': array([0.80553895, 0.19446105], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.9652458], dtype=float32),
#   'logistic': array([0.27582914], dtype=float32),
#   'probabilities': array([0.72417086, 0.27582914], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.0593185], dtype=float32),
#   'logistic': array([0.25743973], dtype=float32),
#   'probabilities': array([0.7425603 , 0.25743973], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.8249407], dtype=float32),
#   'logistic': array([0.13884208], dtype=float32),
#   'probabilities': array([0.8611579 , 0.13884209], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.3844972], dtype=float32),
#   'logistic': array([0.20028773], dtype=float32),
#   'probabilities': array([0.7997123 , 0.20028771], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.17885554], dtype=float32),
#   'logistic': array([0.54459506], dtype=float32),
#   'probabilities': array([0.45540494, 0.54459506], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.78207505], dtype=float32),
#   'logistic': array([0.6861271], dtype=float32),
#   'probabilities': array([0.31387284, 0.6861272 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.51048446], dtype=float32),
#   'logistic': array([0.62492], dtype=float32),
#   'probabilities': array([0.37507996, 0.62492007], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.8013594], dtype=float32),
#   'logistic': array([0.6902652], dtype=float32),
#   'probabilities': array([0.3097348, 0.6902652], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.2421292], dtype=float32),
#   'logistic': array([0.43976173], dtype=float32),
#   'probabilities': array([0.5602383, 0.4397617], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.86285925], dtype=float32),
#   'logistic': array([0.29674232], dtype=float32),
#   'probabilities': array([0.7032577 , 0.29674232], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.07223427], dtype=float32),
#   'logistic': array([0.51805073], dtype=float32),
#   'probabilities': array([0.4819493 , 0.51805073], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.4871769], dtype=float32),
#   'logistic': array([0.18434584], dtype=float32),
#   'probabilities': array([0.81565416, 0.18434584], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.7045114], dtype=float32),
#   'logistic': array([0.15387693], dtype=float32),
#   'probabilities': array([0.8461231 , 0.15387698], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.4911189], dtype=float32),
#   'logistic': array([0.18375388], dtype=float32),
#   'probabilities': array([0.81624615, 0.18375383], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.0057925], dtype=float32),
#   'logistic': array([0.49855188], dtype=float32),
#   'probabilities': array([0.5014481 , 0.49855185], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-2.7608805], dtype=float32),
#   'logistic': array([0.05947509], dtype=float32),
#   'probabilities': array([0.9405249 , 0.05947509], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.9947432], dtype=float32),
#   'logistic': array([0.26997626], dtype=float32),
#   'probabilities': array([0.73002374, 0.2699762 ], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.5667278], dtype=float32),
#   'logistic': array([0.17268337], dtype=float32),
#   'probabilities': array([0.8273166 , 0.17268337], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.0129844], dtype=float32),
#   'logistic': array([0.2663962], dtype=float32),
#   'probabilities': array([0.7336038, 0.2663962], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.1131612], dtype=float32),
#   'logistic': array([0.24728203], dtype=float32),
#   'probabilities': array([0.752718  , 0.24728201], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.9405603], dtype=float32),
#   'logistic': array([0.28078717], dtype=float32),
#   'probabilities': array([0.71921283, 0.2807872 ], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([1.1539189], dtype=float32),
#   'logistic': array([0.760226], dtype=float32),
#   'probabilities': array([0.23977402, 0.760226  ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.5367849], dtype=float32),
#   'logistic': array([0.17700312], dtype=float32),
#   'probabilities': array([0.82299685, 0.17700315], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.9547912], dtype=float32),
#   'logistic': array([0.12403181], dtype=float32),
#   'probabilities': array([0.8759681 , 0.12403186], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.36234033], dtype=float32),
#   'logistic': array([0.5896068], dtype=float32),
#   'probabilities': array([0.41039318, 0.5896069 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.07666636], dtype=float32),
#   'logistic': array([0.4808428], dtype=float32),
#   'probabilities': array([0.51915723, 0.48084283], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([1.6836518], dtype=float32),
#   'logistic': array([0.8433875], dtype=float32),
#   'probabilities': array([0.15661252, 0.8433875 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.5930382], dtype=float32),
#   'logistic': array([0.6440619], dtype=float32),
#   'probabilities': array([0.35593805, 0.6440619 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.9298584], dtype=float32),
#   'logistic': array([0.12676625], dtype=float32),
#   'probabilities': array([0.87323374, 0.12676625], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.509794], dtype=float32),
#   'logistic': array([0.6247582], dtype=float32),
#   'probabilities': array([0.37524185, 0.6247582 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)}]

# %%
dnn_model = tf.estimator.DNNClassifier(hidden_units=[10, 10, 10], feature_columns=feat_cols,
                                      n_classes=2)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmp0os1pya_
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/tmp0os1pya_', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f291c3b1d68>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
# dnn_model.train(input_fn=input_func, steps=1000)

# %%
embedded_group_col = tf.feature_column.embedding_column(assigned_group, dimension=4)

# %%
feat_cols = [num_preg, plasma_gluc, dias_press, tricep, insulin, bmi, diabetes_pedigree, embedded_group_col, age_bucket]

# %%
input_func = tf.estimator.inputs.pandas_input_fn(X_train, y_train, batch_size=10, 
                                            num_epochs=1000, shuffle=True)

# %%
dnn_model = tf.estimator.DNNClassifier(hidden_units=[10, 10, 10], feature_columns=feat_cols, n_classes=2)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpn7_ndcv4
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/tmpn7_ndcv4', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f2968b497f0>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
dnn_model.train(input_fn=input_func, steps=1000)
# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From /home/vasanthakumar/.local/share/virtualenvs/tf_pierian-7Jy-WT6u/lib/python3.6/site-packages/tensorflow/python/feature_column/feature_column_v2.py:2997: VocabularyListCategoricalColumn._num_buckets (from tensorflow.python.feature_column.feature_column_v2) is deprecated and will be removed after 2018-11-30.
# Instructions for updating:
# The old _FeatureColumn APIs are being deprecated. Please use the new FeatureColumn APIs instead.
# WARNING:tensorflow:From /home/vasanthakumar/.local/share/virtualenvs/tf_pierian-7Jy-WT6u/lib/python3.6/site-packages/tensorflow/python/ops/array_grad.py:425: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into /tmp/tmpn7_ndcv4/model.ckpt.
# INFO:tensorflow:loss = 6.996713, step = 1
# INFO:tensorflow:global_step/sec: 226.604
# INFO:tensorflow:loss = 7.4752054, step = 101 (0.448 sec)
# INFO:tensorflow:global_step/sec: 294.243
# INFO:tensorflow:loss = 8.509233, step = 201 (0.338 sec)
# INFO:tensorflow:global_step/sec: 278.49
# INFO:tensorflow:loss = 3.850925, step = 301 (0.363 sec)
# INFO:tensorflow:global_step/sec: 243.084
# INFO:tensorflow:loss = 3.9441905, step = 401 (0.407 sec)
# INFO:tensorflow:global_step/sec: 298.801
# INFO:tensorflow:loss = 5.084853, step = 501 (0.340 sec)
# INFO:tensorflow:global_step/sec: 283.588
# INFO:tensorflow:loss = 4.1229277, step = 601 (0.347 sec)
# INFO:tensorflow:global_step/sec: 274.929
# INFO:tensorflow:loss = 5.971553, step = 701 (0.363 sec)
# INFO:tensorflow:global_step/sec: 268.209
# INFO:tensorflow:loss = 5.6532903, step = 801 (0.374 sec)
# INFO:tensorflow:global_step/sec: 269.674
# INFO:tensorflow:loss = 3.8735125, step = 901 (0.373 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into /tmp/tmpn7_ndcv4/model.ckpt.
# INFO:tensorflow:Loss for final step: 7.714016.

# %%
eval_input_func = tf.estimator.inputs.pandas_input_fn(x=X_test, y=y_test, batch_size=10, num_epochs=1, shuffle=False)

# %%
dnn_model.evaluate(eval_input_func)
# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-03-06T12:39:23Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpn7_ndcv4/model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-03-06-12:39:24
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.75757575, accuracy_baseline = 0.64935064, auc = 0.83843625, auc_precision_recall = 0.7237227, average_loss = 0.4738523, global_step = 1000, label/mean = 0.35064936, loss = 4.5608287, precision = 0.6506024, prediction/mean = 0.3742637, recall = 0.6666667
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1000: /tmp/tmpn7_ndcv4/model.ckpt-1000
# {'accuracy': 0.75757575,
#  'accuracy_baseline': 0.64935064,
#  'auc': 0.83843625,
#  'auc_precision_recall': 0.7237227,
#  'average_loss': 0.4738523,
#  'label/mean': 0.35064936,
#  'loss': 4.5608287,
#  'precision': 0.6506024,
#  'prediction/mean': 0.3742637,
#  'recall': 0.6666667,
#  'global_step': 1000}
